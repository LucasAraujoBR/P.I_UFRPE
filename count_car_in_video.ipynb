# %% [markdown]
# # Pré-Processamento das Imagens

# %%
import cv2
import numpy as np
import os

def preprocess_image(image):
    # Redimensiona a imagem se necessário
    image = cv2.resize(image, (640, 480))
    
    # Conversão para escala de cinza
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Normalização da iluminação com CLAHE
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    gray = clahe.apply(gray)
    
    # Remoção de ruído com GaussianBlur
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    
    # Aplicação de Canny para realçar bordas
    edges = cv2.Canny(blurred, 50, 150)
    
    # Aplica a segmentação de cor para destacar veículos
    lower_bound = np.array([0, 0, 120])  # Exemplo para destacar tons mais escuros ou avermelhados (ajuste conforme necessário)
    upper_bound = np.array([255, 255, 255])
    mask = cv2.inRange(image, lower_bound, upper_bound)
    
    # Combina as bordas com a máscara de segmentação
    combined = cv2.bitwise_and(edges, edges, mask=mask)
    
    # Operações morfológicas para refinar a imagem
    kernel = np.ones((5,5), np.uint8)
    morphed = cv2.morphologyEx(combined, cv2.MORPH_CLOSE, kernel)
    
    return morphed

def process_images(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        if filename.endswith(".PNG") or filename.endswith(".png"):
            image_path = os.path.join(input_folder, filename)
            image = cv2.imread(image_path)
            if image is None:
                print(f"Could not read the image {filename}. Skipping.")
                continue
            
            processed_image = preprocess_image(image)
            
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, processed_image)
            print(f'Processed and saved: {output_path}')

# Caminho da pasta de imagens originais
input_folder = 'dataset/images'
# Caminho para salvar as imagens pré-processadas
output_folder = 'dataset/processed_images'

# Processa as imagens
process_images(input_folder, output_folder)
# Out:
# Processed and saved: dataset/processed_images\frame_000000.PNG
# Processed and saved: dataset/processed_images\frame_000001.PNG
# Processed and saved: dataset/processed_images\frame_000002.PNG
# Processed and saved: dataset/processed_images\frame_000003.PNG
# Processed and saved: dataset/processed_images\frame_000004.PNG
# Processed and saved: dataset/processed_images\frame_000005.PNG
# Processed and saved: dataset/processed_images\frame_000006.PNG
# Processed and saved: dataset/processed_images\frame_000007.PNG
# Processed and saved: dataset/processed_images\frame_000008.PNG
# Processed and saved: dataset/processed_images\frame_000009.PNG
# Processed and saved: dataset/processed_images\frame_000010.PNG
# Processed and saved: dataset/processed_images\frame_000011.PNG
# Processed and saved: dataset/processed_images\frame_000012.PNG
# Processed and saved: dataset/processed_images\frame_000013.PNG
# Processed and saved: dataset/processed_images\frame_000014.PNG
# Processed and saved: dataset/processed_images\frame_000015.PNG
# Processed and saved: dataset/processed_images\frame_000016.PNG
# Processed and saved: dataset/processed_images\frame_000017.PNG
# Processed and saved: dataset/processed_images\frame_000018.PNG
# Processed and saved: dataset/processed_images\frame_000019.PNG
# Processed and saved: dataset/processed_images\frame_000020.PNG
# Processed and saved: dataset/processed_images\frame_000021.PNG
# Processed and saved: dataset/processed_images\frame_000022.PNG
# Processed and saved: dataset/processed_images\frame_000023.PNG
# Processed and saved: dataset/processed_images\frame_000024.PNG
# Processed and saved: dataset/processed_images\frame_000025.PNG
# Processed and saved: dataset/processed_images\frame_000026.PNG
# Processed and saved: dataset/processed_images\frame_000027.PNG
# Processed and saved: dataset/processed_images\frame_000028.PNG
# Processed and saved: dataset/processed_images\frame_000029.PNG
# Processed and saved: dataset/processed_images\frame_000030.PNG
# Processed and saved: dataset/processed_images\frame_000031.PNG
# Processed and saved: dataset/processed_images\frame_000032.PNG
# Processed and saved: dataset/processed_images\frame_000033.PNG
# Processed and saved: dataset/processed_images\frame_000034.PNG
# Processed and saved: dataset/processed_images\frame_000035.PNG
# Processed and saved: dataset/processed_images\frame_000036.PNG
# Processed and saved: dataset/processed_images\frame_000037.PNG
# Processed and saved: dataset/processed_images\frame_000038.PNG
# Processed and saved: dataset/processed_images\frame_000039.PNG
# Processed and saved: dataset/processed_images\frame_000040.PNG
# Processed and saved: dataset/processed_images\frame_000041.PNG
# Processed and saved: dataset/processed_images\frame_000042.PNG
# Processed and saved: dataset/processed_images\frame_000043.PNG
# Processed and saved: dataset/processed_images\frame_000044.PNG
# Processed and saved: dataset/processed_images\frame_000045.PNG
# Processed and saved: dataset/processed_images\frame_000046.PNG
# Processed and saved: dataset/processed_images\frame_000047.PNG
# Processed and saved: dataset/processed_images\frame_000048.PNG
# Processed and saved: dataset/processed_images\frame_000049.PNG
# Processed and saved: dataset/processed_images\frame_000050.PNG
# Processed and saved: dataset/processed_images\frame_000051.PNG
# Processed and saved: dataset/processed_images\frame_000052.PNG
# Processed and saved: dataset/processed_images\frame_000053.PNG
# Processed and saved: dataset/processed_images\frame_000054.PNG
# Processed and saved: dataset/processed_images\frame_000055.PNG
# Processed and saved: dataset/processed_images\frame_000056.PNG
# Processed and saved: dataset/processed_images\frame_000057.PNG
# Processed and saved: dataset/processed_images\frame_000058.PNG
# Processed and saved: dataset/processed_images\frame_000059.PNG
# Processed and saved: dataset/processed_images\frame_000060.PNG
# Processed and saved: dataset/processed_images\frame_000061.PNG
# Processed and saved: dataset/processed_images\frame_000062.PNG
# Processed and saved: dataset/processed_images\frame_000063.PNG
# Processed and saved: dataset/processed_images\frame_000064.PNG
# Processed and saved: dataset/processed_images\frame_000065.PNG
# Processed and saved: dataset/processed_images\frame_000066.PNG
# Processed and saved: dataset/processed_images\frame_000067.PNG
# Processed and saved: dataset/processed_images\frame_000068.PNG
# Processed and saved: dataset/processed_images\frame_000069.PNG
# Processed and saved: dataset/processed_images\frame_000070.PNG
# Processed and saved: dataset/processed_images\frame_000071.PNG
# Processed and saved: dataset/processed_images\frame_000072.PNG
# Processed and saved: dataset/processed_images\frame_000073.PNG
# Processed and saved: dataset/processed_images\frame_000074.PNG
# Processed and saved: dataset/processed_images\frame_000075.PNG
# Processed and saved: dataset/processed_images\frame_000076.PNG
# Processed and saved: dataset/processed_images\frame_000077.PNG
# Processed and saved: dataset/processed_images\frame_000078.PNG
# Processed and saved: dataset/processed_images\frame_000079.PNG
# Processed and saved: dataset/processed_images\frame_000080.PNG
# Processed and saved: dataset/processed_images\frame_000081.PNG
# Processed and saved: dataset/processed_images\frame_000082.PNG
# Processed and saved: dataset/processed_images\frame_000083.PNG
# Processed and saved: dataset/processed_images\frame_000084.PNG
# Processed and saved: dataset/processed_images\frame_000085.PNG
# Processed and saved: dataset/processed_images\frame_000086.PNG
# Processed and saved: dataset/processed_images\frame_000087.PNG
# Processed and saved: dataset/processed_images\frame_000088.PNG
# Processed and saved: dataset/processed_images\frame_000089.PNG
# Processed and saved: dataset/processed_images\frame_000090.PNG
# Processed and saved: dataset/processed_images\frame_000091.PNG
# Processed and saved: dataset/processed_images\frame_000092.PNG
# Processed and saved: dataset/processed_images\frame_000093.PNG
# Processed and saved: dataset/processed_images\frame_000094.PNG
# Processed and saved: dataset/processed_images\frame_000095.PNG
# Processed and saved: dataset/processed_images\frame_000096.PNG
# Processed and saved: dataset/processed_images\frame_000097.PNG
# Processed and saved: dataset/processed_images\frame_000098.PNG
# Processed and saved: dataset/processed_images\frame_000099.PNG
# Processed and saved: dataset/processed_images\frame_000100.PNG
# Processed and saved: dataset/processed_images\frame_000101.PNG
# Processed and saved: dataset/processed_images\frame_000102.PNG
# Processed and saved: dataset/processed_images\frame_000103.PNG
# Processed and saved: dataset/processed_images\frame_000104.PNG
# Processed and saved: dataset/processed_images\frame_000105.PNG
# Processed and saved: dataset/processed_images\frame_000106.PNG
# Processed and saved: dataset/processed_images\frame_000107.PNG
# Processed and saved: dataset/processed_images\frame_000108.PNG
# Processed and saved: dataset/processed_images\frame_000109.PNG
# Processed and saved: dataset/processed_images\frame_000110.PNG
# Processed and saved: dataset/processed_images\frame_000111.PNG
# Processed and saved: dataset/processed_images\frame_000112.PNG
# Processed and saved: dataset/processed_images\frame_000113.PNG
# Processed and saved: dataset/processed_images\frame_000114.PNG
# Processed and saved: dataset/processed_images\frame_000115.PNG
# Processed and saved: dataset/processed_images\frame_000116.PNG
# Processed and saved: dataset/processed_images\frame_000117.PNG
# Processed and saved: dataset/processed_images\frame_000118.PNG
# Processed and saved: dataset/processed_images\frame_000119.PNG
# Processed and saved: dataset/processed_images\frame_000120.PNG
# Processed and saved: dataset/processed_images\frame_000121.PNG
# Processed and saved: dataset/processed_images\frame_000122.PNG
# Processed and saved: dataset/processed_images\frame_000123.PNG
# Processed and saved: dataset/processed_images\frame_000124.PNG
# Processed and saved: dataset/processed_images\frame_000125.PNG
# Processed and saved: dataset/processed_images\frame_000126.PNG
# Processed and saved: dataset/processed_images\frame_000127.PNG
# Processed and saved: dataset/processed_images\frame_000128.PNG
# Processed and saved: dataset/processed_images\frame_000129.PNG
# Processed and saved: dataset/processed_images\frame_000130.PNG
# Processed and saved: dataset/processed_images\frame_000131.PNG
# Processed and saved: dataset/processed_images\frame_000132.PNG
# Processed and saved: dataset/processed_images\frame_000133.PNG
# Processed and saved: dataset/processed_images\frame_000134.PNG
# Processed and saved: dataset/processed_images\frame_000135.PNG
# Processed and saved: dataset/processed_images\frame_000136.PNG
# Processed and saved: dataset/processed_images\frame_000137.PNG
# Processed and saved: dataset/processed_images\frame_000138.PNG
# Processed and saved: dataset/processed_images\frame_000139.PNG
# Processed and saved: dataset/processed_images\frame_000140.PNG
# Processed and saved: dataset/processed_images\frame_000141.PNG
# Processed and saved: dataset/processed_images\frame_000142.PNG
# Processed and saved: dataset/processed_images\frame_000143.PNG
# Processed and saved: dataset/processed_images\frame_000144.PNG
# Processed and saved: dataset/processed_images\frame_000145.PNG
# Processed and saved: dataset/processed_images\frame_000146.PNG
# Processed and saved: dataset/processed_images\frame_000147.PNG
# Processed and saved: dataset/processed_images\frame_000148.PNG
# Processed and saved: dataset/processed_images\frame_000149.PNG
# Processed and saved: dataset/processed_images\frame_000150.PNG
# Processed and saved: dataset/processed_images\frame_000151.PNG
# Processed and saved: dataset/processed_images\frame_000152.PNG
# Processed and saved: dataset/processed_images\frame_000153.PNG
# Processed and saved: dataset/processed_images\frame_000154.PNG
# Processed and saved: dataset/processed_images\frame_000155.PNG
# Processed and saved: dataset/processed_images\frame_000156.PNG
# Processed and saved: dataset/processed_images\frame_000157.PNG
# Processed and saved: dataset/processed_images\frame_000158.PNG
# Processed and saved: dataset/processed_images\frame_000159.PNG
# Processed and saved: dataset/processed_images\frame_000160.PNG
# Processed and saved: dataset/processed_images\frame_000161.PNG
# Processed and saved: dataset/processed_images\frame_000162.PNG
# Processed and saved: dataset/processed_images\frame_000163.PNG
# Processed and saved: dataset/processed_images\frame_000164.PNG
# Processed and saved: dataset/processed_images\frame_000165.PNG
# Processed and saved: dataset/processed_images\frame_000166.PNG
# Processed and saved: dataset/processed_images\frame_000167.PNG
# Processed and saved: dataset/processed_images\frame_000168.PNG
# Processed and saved: dataset/processed_images\frame_000169.PNG
# Processed and saved: dataset/processed_images\frame_000170.PNG
# Processed and saved: dataset/processed_images\frame_000171.PNG
# Processed and saved: dataset/processed_images\frame_000172.PNG
# Processed and saved: dataset/processed_images\frame_000173.PNG
# Processed and saved: dataset/processed_images\frame_000174.PNG
# Processed and saved: dataset/processed_images\frame_000175.PNG
# Processed and saved: dataset/processed_images\frame_000176.PNG
# Processed and saved: dataset/processed_images\frame_000177.PNG
# Processed and saved: dataset/processed_images\frame_000178.PNG
# Processed and saved: dataset/processed_images\frame_000179.PNG
# Processed and saved: dataset/processed_images\frame_000180.PNG
# Processed and saved: dataset/processed_images\frame_000181.PNG
# Processed and saved: dataset/processed_images\frame_000182.PNG
# Processed and saved: dataset/processed_images\frame_000183.PNG
# Processed and saved: dataset/processed_images\frame_000184.PNG
# Processed and saved: dataset/processed_images\frame_000185.PNG
# Processed and saved: dataset/processed_images\frame_000186.PNG
# Processed and saved: dataset/processed_images\frame_000187.PNG
# Processed and saved: dataset/processed_images\frame_000188.PNG
# Processed and saved: dataset/processed_images\frame_000189.PNG
# Processed and saved: dataset/processed_images\frame_000190.PNG
# Processed and saved: dataset/processed_images\frame_000191.PNG
# Processed and saved: dataset/processed_images\frame_000192.PNG
# Processed and saved: dataset/processed_images\frame_000193.PNG
# Processed and saved: dataset/processed_images\frame_000194.PNG
# Processed and saved: dataset/processed_images\frame_000195.PNG
# Processed and saved: dataset/processed_images\frame_000196.PNG
# Processed and saved: dataset/processed_images\frame_000197.PNG
# Processed and saved: dataset/processed_images\frame_000198.PNG
# Processed and saved: dataset/processed_images\frame_000199.PNG
# Processed and saved: dataset/processed_images\frame_000200.PNG
# Processed and saved: dataset/processed_images\frame_000201.PNG
# Processed and saved: dataset/processed_images\frame_000202.PNG
# Processed and saved: dataset/processed_images\frame_000203.PNG
# Processed and saved: dataset/processed_images\frame_000204.PNG
# Processed and saved: dataset/processed_images\frame_000205.PNG
# Processed and saved: dataset/processed_images\frame_000206.PNG
# Processed and saved: dataset/processed_images\frame_000207.PNG
# Processed and saved: dataset/processed_images\frame_000208.PNG
# Processed and saved: dataset/processed_images\frame_000209.PNG
# Processed and saved: dataset/processed_images\frame_000210.PNG
# Processed and saved: dataset/processed_images\frame_000211.PNG
# Processed and saved: dataset/processed_images\frame_000212.PNG
# Processed and saved: dataset/processed_images\frame_000213.PNG
# Processed and saved: dataset/processed_images\frame_000214.PNG
# Processed and saved: dataset/processed_images\frame_000215.PNG
# Processed and saved: dataset/processed_images\frame_000216.PNG
# Processed and saved: dataset/processed_images\frame_000217.PNG
# Processed and saved: dataset/processed_images\frame_000218.PNG
# Processed and saved: dataset/processed_images\frame_000219.PNG
# Processed and saved: dataset/processed_images\frame_000220.PNG
# Processed and saved: dataset/processed_images\frame_000221.PNG
# Processed and saved: dataset/processed_images\frame_000222.PNG
# Processed and saved: dataset/processed_images\frame_000223.PNG
# Processed and saved: dataset/processed_images\frame_000224.PNG
# Processed and saved: dataset/processed_images\frame_000225.PNG
# Processed and saved: dataset/processed_images\frame_000226.PNG
# Processed and saved: dataset/processed_images\frame_000227.PNG
# Processed and saved: dataset/processed_images\frame_000228.PNG
# Processed and saved: dataset/processed_images\frame_000229.PNG
# Processed and saved: dataset/processed_images\frame_000230.PNG
# Processed and saved: dataset/processed_images\frame_000231.PNG
# Processed and saved: dataset/processed_images\frame_000232.PNG
# Processed and saved: dataset/processed_images\frame_000233.PNG
# Processed and saved: dataset/processed_images\frame_000234.PNG
# Processed and saved: dataset/processed_images\frame_000235.PNG
# Processed and saved: dataset/processed_images\frame_000236.PNG
# Processed and saved: dataset/processed_images\frame_000237.PNG
# Processed and saved: dataset/processed_images\frame_000238.PNG
# Processed and saved: dataset/processed_images\frame_000239.PNG
# Processed and saved: dataset/processed_images\frame_000240.PNG
# Processed and saved: dataset/processed_images\frame_000241.PNG
# Processed and saved: dataset/processed_images\frame_000242.PNG
# Processed and saved: dataset/processed_images\frame_000243.PNG
# Processed and saved: dataset/processed_images\frame_000244.PNG
# Processed and saved: dataset/processed_images\frame_000245.PNG
# Processed and saved: dataset/processed_images\frame_000246.PNG
# Processed and saved: dataset/processed_images\frame_000247.PNG
# Processed and saved: dataset/processed_images\frame_000248.PNG
# Processed and saved: dataset/processed_images\frame_000249.PNG
# Processed and saved: dataset/processed_images\frame_000250.PNG
# Processed and saved: dataset/processed_images\frame_000251.PNG
# Processed and saved: dataset/processed_images\frame_000252.PNG
# Processed and saved: dataset/processed_images\frame_000253.PNG
# Processed and saved: dataset/processed_images\frame_000254.PNG
# Processed and saved: dataset/processed_images\frame_000255.PNG
# Processed and saved: dataset/processed_images\frame_000256.PNG
# Processed and saved: dataset/processed_images\frame_000257.PNG
# Processed and saved: dataset/processed_images\frame_000258.PNG
# Processed and saved: dataset/processed_images\frame_000259.PNG
# Processed and saved: dataset/processed_images\frame_000260.PNG
# Processed and saved: dataset/processed_images\frame_000261.PNG
# Processed and saved: dataset/processed_images\frame_000262.PNG
# Processed and saved: dataset/processed_images\frame_000263.PNG
# Processed and saved: dataset/processed_images\frame_000264.PNG
# Processed and saved: dataset/processed_images\frame_000265.PNG
# Processed and saved: dataset/processed_images\frame_000266.PNG
# Processed and saved: dataset/processed_images\frame_000267.PNG
# Processed and saved: dataset/processed_images\frame_000268.PNG
# Processed and saved: dataset/processed_images\frame_000269.PNG
# Processed and saved: dataset/processed_images\frame_000270.PNG
# Processed and saved: dataset/processed_images\frame_000271.PNG
# Processed and saved: dataset/processed_images\frame_000272.PNG
# Processed and saved: dataset/processed_images\frame_000273.PNG
# Processed and saved: dataset/processed_images\frame_000274.PNG
# Processed and saved: dataset/processed_images\frame_000275.PNG
# Processed and saved: dataset/processed_images\frame_000276.PNG
# Processed and saved: dataset/processed_images\frame_000277.PNG
# Processed and saved: dataset/processed_images\frame_000278.PNG
# Processed and saved: dataset/processed_images\frame_000279.PNG
# Processed and saved: dataset/processed_images\frame_000280.PNG
# Processed and saved: dataset/processed_images\frame_000281.PNG
# Processed and saved: dataset/processed_images\frame_000282.PNG
# Processed and saved: dataset/processed_images\frame_000283.PNG
# Processed and saved: dataset/processed_images\frame_000284.PNG
# Processed and saved: dataset/processed_images\frame_000285.PNG
# Processed and saved: dataset/processed_images\frame_000286.PNG
# Processed and saved: dataset/processed_images\frame_000287.PNG
# Processed and saved: dataset/processed_images\frame_000288.PNG
# Processed and saved: dataset/processed_images\frame_000289.PNG
# Processed and saved: dataset/processed_images\frame_000290.PNG
# Processed and saved: dataset/processed_images\frame_000291.PNG
# Processed and saved: dataset/processed_images\frame_000292.PNG
# Processed and saved: dataset/processed_images\frame_000293.PNG
# Processed and saved: dataset/processed_images\frame_000294.PNG
# Processed and saved: dataset/processed_images\frame_000295.PNG
# Processed and saved: dataset/processed_images\frame_000296.PNG
# Processed and saved: dataset/processed_images\frame_000297.PNG
# Processed and saved: dataset/processed_images\frame_000298.PNG
# Processed and saved: dataset/processed_images\frame_000299.PNG
# Processed and saved: dataset/processed_images\frame_000300.PNG

# %% [markdown]
# # Integração com YoloV10

# %%
import torch
from yolov10.models.common import DetectMultiBackend
import cv2

def detect_vehicles(video_path):
    model = DetectMultiBackend(weights='path_to_yolov10_weights.pth')
    cap = cv2.VideoCapture(video_path)
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        results = model(frame)
        results.show()  # Exibe as detecções
    
    cap.release()

# Vídeo pré-processado
processed_video_path = 'path_to_save_processed_video.avi'

# Realiza a detecção no vídeo pré-processado
detect_vehicles(processed_video_path)
